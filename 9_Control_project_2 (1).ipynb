# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Общие-сведения-о-полученных-данных." data-toc-modified-id="Общие-сведения-о-полученных-данных.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Общие сведения о полученных данных.</a></span></li><li><span><a href="#Расчет-эффективности-обогащения." data-toc-modified-id="Расчет-эффективности-обогащения.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Расчет эффективности обогащения.</a></span></li><li><span><a href="#Общие-сведения-о-данных-в-тестовой-выборке." data-toc-modified-id="Общие-сведения-о-данных-в-тестовой-выборке.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Общие сведения о данных в тестовой выборке.</a></span></li><li><span><a href="#Общие-сведения-о-данных-в-обучающей-выборке." data-toc-modified-id="Общие-сведения-о-данных-в-обучающей-выборке.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Общие сведения о данных в обучающей выборке.</a></span></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Предобработка данных.</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрация-металлов-на-различных-этапах-очистки." data-toc-modified-id="Концентрация-металлов-на-различных-этапах-очистки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Концентрация металлов на различных этапах очистки.</a></span><ul class="toc-item"><li><span><a href="#Золото." data-toc-modified-id="Золото.-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Золото.</a></span></li><li><span><a href="#Серебро." data-toc-modified-id="Серебро.-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Серебро.</a></span></li><li><span><a href="#Свинец." data-toc-modified-id="Свинец.-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Свинец.</a></span></li></ul></li><li><span><a href="#Распределение-размеров-гранул-сырья." data-toc-modified-id="Распределение-размеров-гранул-сырья.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья.</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях." data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях.</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Функция-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучение-моделей." data-toc-modified-id="Обучение-моделей.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение моделей.</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия." data-toc-modified-id="Линейная-регрессия.-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Линейная регрессия.</a></span></li><li><span><a href="#Регрессия-решающго-дерева." data-toc-modified-id="Регрессия-решающго-дерева.-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Регрессия решающго дерева.</a></span></li><li><span><a href="#Случайный-лес-решающих-деревьев." data-toc-modified-id="Случайный-лес-решающих-деревьев.-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Случайный лес решающих деревьев.</a></span></li><li><span><a href="#Лучшая-модель." data-toc-modified-id="Лучшая-модель.-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Лучшая модель.</a></span></li></ul></li><li><span><a href="#Проверка-лучшей-моделей." data-toc-modified-id="Проверка-лучшей-моделей.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка лучшей моделей.</a></span><ul class="toc-item"><li><span><a href="#Проверка-на-тестовой-выборке." data-toc-modified-id="Проверка-на-тестовой-выборке.-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Проверка на тестовой выборке.</a></span></li><li><span><a href="#Проверка-на-адекватность." data-toc-modified-id="Проверка-на-адекватность.-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Проверка на адекватность.</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод." data-toc-modified-id="Общий-вывод.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Общий вывод.</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# <h1>Описание проекта</h1>
# Подготовка прототипа модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# По техническому заанию модель должна предсказать коэффициент восстановления золота из золотосодержащей руды на основании данных с параметрами добычи и очистки.
#
# Модель необходима для оптимизации производства, чтобы не запускать предприятие с убыточными характеристиками.
#
# **Ход работы**:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats as st
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import StandardScaler
from numpy.random import RandomState
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# %%
# исходные данные
try:
    data = pd.read_csv('gold_recovery_full_new.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv')

# %%
# обучающие данные
try:
    data_train = pd.read_csv('gold_recovery_train_new.csv')
except:
    data_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv')

# %%
# тестовые данные
try:
    data_test = pd.read_csv('gold_recovery_test_new.csv')
except:
    data_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv')

# %% [markdown]
# ### Общие сведения о полученных данных.
#
# Рассмотрим полученные данные.

# %%
data.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %% [markdown]
# В полученных даных мы видим следующие сведения:
# 1. данные о дате и времени(date)
# 2. этапы обработки(финальный(final), первичная обработка(primary_cleaner), флотация(rougher) и вторичная очистка(secondary_cleaner))
# 3. признаки этапа(параметры входящего сырья(input), параметры исходящего продукта(output), текущее состояние этапа(state) и расчётные характеристики(calculation))
# 4. параметры этапа(концентрация(concentrate), отвальные хвосты(tail), флотационная установка(float_bank), размер гранул сырья или скорость подачи(feed))
#
# Среди 19439 строк есть данные с пропусками.
#
# Так как известно, что полученные данные сырые, проверим есть ли пропуски и дубликаты в данных.

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# secondary_cleaner.output.tail_sol           1748
# rougher.input.floatbank11_xanthate           453
# rougher.state.floatbank10_e_air              436
# primary_cleaner.output.concentrate_sol       370
# secondary_cleaner.state.floatbank2_a_air     220
#                                             ...
# rougher.state.floatbank10_d_level              0
# rougher.state.floatbank10_d_air                0
# rougher.output.tail_pb                         0
# rougher.output.tail_sol                        0
# date                                           0
# Length: 87, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# На всех этапах поизводства есть пропуски в данных. Больше всего пропусков наблюдается в разделах концентрации(concentrate), флотации(floatbank) и остаточной концентрации(tail). Дублирующихся данных не обнаружено.

# %%
data.hist(bins=20, figsize=(30, 40))
plt.show()

# %% [markdown]
# Распределение значений практически всех стролбцов таблицы близко к нормальному. Судя по значениям столбцов tail их значения указаны в процентах.

# %% [markdown]
# ### Расчет эффективности обогащения.
#
# Создадим функцию, расчитывающую эффективность процесса обогощения золотосодержащей руды. Для этого воспользуемся формулой:
# $$Recovery = \frac{C*(F-T)}{F*(C-T)}* 100\% $$ где:
#
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.

# %%
def recovery(feed_in, concentrate_out, tail_out):
    rec = concentrate_out * (feed_in - tail_out) / \
          (feed_in * (concentrate_out - tail_out)) * 100
    return rec

# %% [markdown]
# Проверим коректность формулы на обучающих данных. В качестве критерия оценки возьмем sMAPE (симметричное среднее абсолютное процентное отклонение). Для этого воспользуемся формулой:
# $$sMAPE = \frac{1}{N} \sum_{ i=1 }^{ N } \frac{|y_i - \hat{y_i}|}{|y_i| + |\hat{y_i}|/2}* 100\% $$ где:
#
# * N — количество элементов в выборке;
# * y_i — значение целевого признака для i-того элемента;
# * \hat{y_i} — значение предсказания для i-того элемента.

# %%
def s_mape(target, prediction):
   
    numerator = abs(target - prediction)
    denominator = (abs(target) + abs(prediction))/2
   
    return np.mean(numerator / denominator)* 100

# %%
prediction_test = pd.Series(recovery(data_train['rougher.input.feed_au'],
                            data_train['rougher.output.concentrate_au'],
                            data_train['rougher.output.tail_au']))

# %%
mae = mean_absolute_error(data_train['rougher.output.recovery'], prediction_test)

print('Cредняя абсолютная ошибка на обучающих данных равна', mae, '.')
# Out:
# Cредняя абсолютная ошибка на обучающих данных равна 9.73512347450521e-15 .

# %% [markdown]
# Функция расчета дает пренебрежимо малое отличие от истинных значей, о чем свидетельствует средняя абсолютная ошибка равная $9.74 х 10^{-15} \%$.

# %% [markdown]
# ### Общие сведения о данных в тестовой выборке.
#
# Посмотрим, что соддерит в себе файл тестовой выборки.

# %%
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
print('Список столбцов, отсутствующих в тестовой выборке:')
set(list(data_train)) - set(list(data_test))
# Out:
# Список столбцов, отсутствующих в тестовой выборке:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
# ...

# %% [markdown]
# В данной тестовой выборке мы получили сведения о полученных образцах до начала обработки, характеристики проводимых этапов и информацию о добавлении примесей в начале этапа первичной обработки. Из этого получется, что у нас отсутствуют расчетные велечины(например, концентрация по окончании процесса - output.concentrate_ag и отвальные хвосты - output.tail_sol). Данные параметры можно отнести к прогнозируемым. Также отсутсвуют значения целевого признака, без которых в дальнейшем мы не сможем оценить корректность работы обученной модели. Мы можем добавить их из общих данных.

# %%
data_test = data_test.merge(data[['date', 'final.output.recovery',
                                  'rougher.output.recovery']], 
                            how='outer', on='date')\
                     .dropna(subset=['rougher.input.feed_au'])

# %%
# проверка добавления столбцов
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %% [markdown]
# ### Общие сведения о данных в обучающей выборке.
#
# Посмотрим, что соддерит в себе файл обучающей выборки.

# %%
data_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# В полученных обучающих данных содержатся все теже столбцы, что и в общих данных. Разное количество доступных параметров может стать проблемой при обучении модели и ее дальнейшей проверки.

# %%
delete_colums = ['final.output.concentrate_ag', 
                 'final.output.concentrate_pb',
                 'final.output.concentrate_sol', 
                 'final.output.concentrate_au',
                 'final.output.tail_ag', 
                 'final.output.tail_pb',
                 'final.output.tail_sol', 
                 'final.output.tail_au',
                 'primary_cleaner.output.concentrate_ag',
                 'primary_cleaner.output.concentrate_pb',
                 'primary_cleaner.output.concentrate_sol',
                 'primary_cleaner.output.concentrate_au',
                 'primary_cleaner.output.tail_ag', 
                 'primary_cleaner.output.tail_pb',
                 'primary_cleaner.output.tail_sol',
                 'primary_cleaner.output.tail_au',
                 'rougher.calculation.sulfate_to_au_concentrate',
                 'rougher.calculation.floatbank10_sulfate_to_au_feed',
                 'rougher.calculation.floatbank11_sulfate_to_au_feed',
                 'rougher.calculation.au_pb_ratio', 
                 'rougher.output.concentrate_ag',
                 'rougher.output.concentrate_pb', 
                 'rougher.output.concentrate_sol',
                 'rougher.output.concentrate_au', 
                 'rougher.output.tail_ag',
                 'rougher.output.tail_pb', 
                 'rougher.output.tail_sol',
                 'rougher.output.tail_au', 
                 'secondary_cleaner.output.tail_ag',
                 'secondary_cleaner.output.tail_pb',
                 'secondary_cleaner.output.tail_sol',
                 'secondary_cleaner.output.tail_au'
                ]

# %% [markdown]
# ### Предобработка данных.
#
# В общих данных не было дубликатов, но были пропуски. Проверим, не появились ли новые ошибки при делении данных.

# %%
# пропуски в обучающей выборке
print('Процент пропусков в обучающих данных:')
data_train.isnull().mean().sort_values(ascending=False).head(15)
# Out:
# Процент пропусков в обучающих данных:
# secondary_cleaner.output.tail_sol           0.113436
# rougher.state.floatbank10_e_air             0.030815
# rougher.input.floatbank11_xanthate          0.030249
# primary_cleaner.output.concentrate_sol      0.020213
# secondary_cleaner.state.floatbank2_a_air    0.015337
# final.output.concentrate_sol                0.014913
# rougher.input.feed_size                     0.010177
# primary_cleaner.input.xanthate              0.007068
# rougher.input.feed_pb                       0.007068
# final.output.tail_pb                        0.007068
# primary_cleaner.output.concentrate_pb       0.006078
# rougher.input.feed_sol                      0.005513
# primary_cleaner.output.tail_sol             0.003251
# rougher.input.floatbank11_sulfate           0.002544
# primary_cleaner.input.depressant            0.002262
# dtype: float64

# %%
# пропуски в тестовой выборке
print('Процент пропусков в тестовых данных:')
data_test.isnull().mean().sort_values(ascending=False).head(10)
# Out:
# Процент пропусков в тестовых данных:
# rougher.input.floatbank11_xanthate          0.004726
# rougher.input.feed_sol                      0.003970
# secondary_cleaner.state.floatbank3_a_air    0.001701
# rougher.input.floatbank11_sulfate           0.001512
# primary_cleaner.input.depressant            0.000945
# rougher.input.floatbank10_sulfate           0.000945
# primary_cleaner.input.xanthate              0.000756
# primary_cleaner.input.sulfate               0.000756
# secondary_cleaner.state.floatbank2_a_air    0.000567
# rougher.input.feed_rate                     0.000567
# dtype: float64

# %%
print('Обнаружено дублирующихся данных в обучающей выборке:',
      data_train.duplicated().sum())
# Out:
# Обнаружено дублирующихся данных в обучающей выборке: 0

# %%
print('Обнаружено дублирующихся данных в тестовой выборке:',
      data_test.duplicated().sum())
# Out:
# Обнаружено дублирующихся данных в тестовой выборке: 0

# %% [markdown]
# Задвоения данных в обеих выборках не обнаружено, а вот пропущенных данных у нас достаточно много. В тестовой выборке процент пропусков не превыщает 0,5%, а в обучающей выборке процент строк с пропусками не превышает 3,1%. Так как по условию процесса нам известно, что соседние иттерации имеют близкие значения, заполним пропуски соседнимизначениями.

# %%
data_train = data_train.fillna(method='ffill').fillna(method='bfill')

# %%
print('Проверка оставшихся пропусков:')
data_train.isnull().mean().sort_values(ascending=False).head()
# Out:
# Проверка оставшихся пропусков:
# date                                 0.0
# rougher.state.floatbank10_b_air      0.0
# rougher.state.floatbank10_f_air      0.0
# rougher.state.floatbank10_e_level    0.0
# rougher.state.floatbank10_e_air      0.0
# dtype: float64

# %%
data_test = data_test.fillna(method='ffill').fillna(method='bfill')

# %%
print('Проверка оставшихся пропусков:')
data_test.isnull().mean().sort_values(ascending=False).head()
# Out:
# Проверка оставшихся пропусков:
# date                                        0.0
# secondary_cleaner.state.floatbank3_b_air    0.0
# rougher.state.floatbank10_d_level           0.0
# rougher.state.floatbank10_e_air             0.0
# rougher.state.floatbank10_e_level           0.0
# dtype: float64

# %% [markdown]
# ## Анализ данных
#
# Преступим к анализу данных:
# - как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки
# - распределения размеров гранул сырья на обучающей и тестовой выборках
# - суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %% [markdown]
# ### Концентрация металлов на различных этапах очистки.
#
# Рассмотрим, как изменяется концентрация разных металлов(Au, Ag, Pb) на различных этапах очистки. Создадим функцию для построения гистограм и ящика с усами.

# %%
def metal_hist (metal_type, name):
    
    columns = ['rougher.input.feed_' + metal_type,
               'rougher.output.concentrate_' + metal_type, 
               'primary_cleaner.output.concentrate_' + metal_type, 
               'final.output.concentrate_' + metal_type]
        
    for column in columns:
        data_train[column].hist(bins=30, figsize=(10, 8), alpha=0.35)
        
    plt.legend(['исходное сырье', 'флотация', 
                'первичная очиска','вторичная очистка'])
    plt.title('Концентрация ' + name)
    plt.xlabel('концентрация, %')
    plt.ylabel('руда')
    plt.show()
    
    for column in columns:
        data.boxplot(column=column)
        plt.title('Распределение значений ' + name +
                  ' на этапе ' + column)
        plt.show()

# %% [markdown]
# #### Золото.
#
# Начнем непосредствено с золота.

# %%
metal_hist('au', 'золота')

# %% [markdown]
# На гистограме можно увидеть, как с каждым этапом обработки возрастает концентрация золота в образце. А по графикахам выбрасов можно заметить, что пустая руда встречается на всех этапах. Но они также подтверждают увеличение концентрации золота с 2,5-14% в исходной руде до 39-51% в обработанной.

# %% [markdown]
# #### Серебро.
#
# Продолжим наше исследование с концентрацией серебра.

# %%
metal_hist('ag', 'серебра')

# %% [markdown]
# На гистограме серебра мы видим, что концентрация металла сначала возрастает, а затем снова снижается к концу процесса очистки. На графикахах выбрасов можно заметить, что концентрация серебра по завершении процесса ниже чем в начале, 3-15% и 2-8% соответственно.

# %% [markdown]
# #### Свинец.
#
# Завершим последним из распространненных металлов примесей - свинцом.

# %%
metal_hist('pb', 'свинца')

# %% [markdown]
# На гистограме свинца хорошо видно, что концентрация металла сначала возрастает на первых двух этапах обработки. Между значениями второго этапа и финальным образцом значения практически не меняются. На графикахах выбрасов концентрация в руде 1-6,5%, после флотации 4-11%, затем 5-15% и на выходе остается 6-13%.

# %% [markdown]
# ### Распределение размеров гранул сырья.
#
# Чтобы наша предсказывающая модель работала корректно, нам нужно убедиться, нет ли дисбаланса в размерах гранул сырья на обучающей и тестовой выборках. Так как это может сильно повлиять на качество дальнейшей работы.

# %%
for param in ['rougher.input.feed_size', 
              'primary_cleaner.input.feed_size']:
    data_train.boxplot(column=param)
    data_test.boxplot(column=param)
    if param == 'rougher.input.feed_size':
        plt.ylim(10, 100)
    else:
        plt.ylim(5, 10)
    plt.show()

# %% [markdown]
# На графиках хорошо видно наслоение значений, перекрывающие друг друга. Следовательно диапазоны в обучающих и тестовых данных схожи. Основная масса размеров гранул сырья на входе этапа обогащения попадает в интервал 25-90, а на этапе первичной очистки 5,8 - 8,8 для обеих выборок.

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях.
#
# Рассмотрим суммарнаую концентрацию всех металлов на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
data_train['rougher.input.feed_sum'] = \
                data_train['rougher.input.feed_ag'] + \
                data_train['rougher.input.feed_au'] + \
                data_train['rougher.input.feed_pb']

# %%
data_train['rougher.output.concentrate_sum'] = \
                data_train['rougher.output.concentrate_ag'] + \
                data_train['rougher.output.concentrate_au'] + \
                data_train['rougher.output.concentrate_pb']

# %%
data_train['primary_cleaner.output.concentrate_sum'] = \
                data_train['primary_cleaner.output.concentrate_ag'] + \
                data_train['primary_cleaner.output.concentrate_au'] + \
                data_train['primary_cleaner.output.concentrate_pb']

# %%
data_train['final.output.concentrate_sum'] = \
                data_train['final.output.concentrate_ag'] + \
                data_train['final.output.concentrate_au'] + \
                data_train['final.output.concentrate_pb']

# %%
columns = ['rougher.input.feed_sum',
           'rougher.output.concentrate_sum',
           'primary_cleaner.output.concentrate_sum',
           'final.output.concentrate_sum']
        
for column in columns:
    data_train[column].hist(bins=30, figsize=(10, 8), alpha=0.35)
        
plt.legend(['исходное сырье', 'флотация', 'первичная очиска','вторичная очистка'])
plt.title('Суммарная концентрация металлов')
plt.xlabel('концентрация, %')
plt.ylabel('руда')
plt.show()

# %% [markdown]
# По графику суммарной концентрации металлов видно, как с каждым этапом пройденным этапом очистки концентрация металлов рестет. После флотации концентрация возрасла практически в 2 раза, а после первичной и вторичной обработки возрастает уже не так сильно.

# %% [markdown]
# На сколько много аномалий встречается в суммарных данных.

# %%
for column in columns:
    data_train.boxplot(column=column)
    plt.title('Распределение значений для ' + column)
    
    if column == 'rougher.input.feed_sum':
        plt.ylim(5, 35)
    elif column == 'rougher.output.concentrate_sum':
        plt.ylim(30, 50)
    elif column == 'primary_cleaner.output.concentrate_sum':
        plt.ylim(40, 60)
    else:
        plt.ylim(55, 65)

    plt.show()

# %% [markdown]
# Исключим строки с явными выбросами суммарных значений по всем этапам для обучающих данным. Это должно повысить качество предсказаний модели.

# %%
# исключение выбросов rougher.input.feed_sum
data_cleared_train = data_train.loc[
    (data_train['rougher.input.feed_sum'] > 7) & \
    (data_train['rougher.input.feed_sum'] < 32)]
# исключение выбросов rougher.output.concentrate_sum
data_cleared_train = data_cleared_train.loc[
    (data_cleared_train['rougher.output.concentrate_sum'] > 31) & \
    (data_cleared_train['rougher.output.concentrate_sum'] < 48)]
# исключение выбросов primary_cleaner.output.concentrate_sum
data_cleared_train = data_cleared_train.loc[
    (data_cleared_train['primary_cleaner.output.concentrate_sum'] > 43) & \
    (data_cleared_train['primary_cleaner.output.concentrate_sum'] < 59)]
# исключение выбросов final.output.concentrate_sum
data_cleared_train = data_cleared_train.loc[
    (data_cleared_train['final.output.concentrate_sum'] > 56) & \
    (data_cleared_train['final.output.concentrate_sum'] < 64)]

# %%
print('Количество строк после исключения выбросов:', 
      data_cleared_train.shape[0], 'строк.')
# Out:
# Количество строк после исключения выбросов: 12353 строк.

# %% [markdown]
# Теперь можно исключить столбцы, которых нет в тестовой выборке.

# %%
data_cleared_train = data_cleared_train.drop(columns=delete_colums)\
                                       .drop(columns=columns)

# %%
data_cleared_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12353 entries, 0 to 14148
# Data columns (total 55 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        12353 non-null  object
#  1   final.output.recovery                       12353 non-null  float64
#  2   primary_cleaner.input.sulfate               12353 non-null  float64
#  3   primary_cleaner.input.depressant            12353 non-null  float64
#  4   primary_cleaner.input.feed_size             12353 non-null  float64
#  5   primary_cleaner.input.xanthate              12353 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_air      12353 non-null  float64
#  7   primary_cleaner.state.floatbank8_a_level    12353 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_air      12353 non-null  float64
# ...

# %% [markdown]
# ## Модель
#
# Теперь можем перйти к созданию предсказывающей модели. Модели нужно спрогнозировать сразу две величины - эффективность обогащения чернового концентрата(rougher.output.recovery) и эффективность обогащения финального концентрата(final.output.recovery).
#
# Для этого проведем следующие исследования:
# - создадим функцию для вычисления итоговой sMAPE
# - обучим несколько моделей и оценим их качество кросс-валидацией
# - выберем лучшую моодель и проведем проверку на тестовых данных

# %% [markdown]
# ### Функция для вычисления итоговой sMAPE.
#
# Так как модель прогнозирует сразу 2 признака, внесем корректировку в расчёт критерия оценки sMAPE (симметричное среднее абсолютное процентное отклонение). Теперь он будет расчитываться по следующей формуле:
# $$sMAPE = 25\% * sMAPE(rougher) + 75\% * sMAPE(final)$$ где:
#
# * sMAPE(rougher) — симметричное среднее абсолютное процентное отклонение после этапа флотации;
# * sMAPE(final) — симметричное среднее абсолютное процентное отклонение после проведения всех этапов очистки.

# %%
def s_mape_final(rougher, final):
    
    return 0.25 * rougher + 0.75 * final

# %% [markdown]
# ### Обучение моделей.
#
# Так как целевых признакаа два, разделим обучение на два этапа - предсказание значений после флотации и предсказание значений финальной обработки. На каждом этапе обучим модели отдельно. Для повышения эффективности обучения воспользуемся методом кросс-валидации.
#
# Для обучения выберем следующие модели регрессий:
# - линейная
# - решающее дерево
# - случайный лес решающих деревьев
#
# Предварительно проведем выделение целевого признака для каждой подбрки данных. Также уберем из данных для предсказаний этапа флотации информацию о последующих обработках.

# %%
features_rougher = data_cleared_train.iloc[:, 14:37]\
                                     .drop(['rougher.output.recovery'], axis=1)

# %%
target_rougher = data_cleared_train['rougher.output.recovery']

# %%
features_rougher_test = data_test.iloc[:, 13:35]

# %%
target_rougher_test = data_test['rougher.output.recovery']

# %%
features_final = data_cleared_train.drop(['date', 'rougher.output.recovery',
                                          'final.output.recovery'], axis = 1)

# %%
target_final = data_cleared_train['final.output.recovery']

# %%
features_final_test = data_test.drop(['date','rougher.output.recovery',
                                      'final.output.recovery'], axis = 1)

# %%
target_final_test = data_test['final.output.recovery']

# %%
scorer = make_scorer(s_mape, greater_is_better = False)

# %%
# функция для расчета среднего откланения предсказания
def cross_valid(features, target, model):
    
    pipe = make_pipeline(StandardScaler(), model)
       
    scores = cross_val_score(pipe, features, 
                             target, cv=7, scoring=scorer) 
    
    final_score = (scores * (-1)).mean()
    
    return final_score

# %% [markdown]
# #### Линейная регрессия.
#
# Начнем с одной из самых простых моделей - линейной регрессии.

# %%
rougher_model_linear = LinearRegression() 
rougher_linear = \
    cross_valid(features_rougher, target_rougher, rougher_model_linear)
print('На этапе флотации sMAPE модели составляет',
      '%.2f' %rougher_linear ,'%.')
# Out:
# На этапе флотации sMAPE модели составляет 5.75 %.

# %%
final_model_linear = LinearRegression() 
final_linear = \
    cross_valid(features_final, target_final, final_model_linear)
print('На финальном этапе sMAPE модели составляет',
      '%.2f' %final_linear ,'%.')
# Out:
# На финальном этапе sMAPE модели составляет 10.46 %.

# %%
end_linear = s_mape_final(rougher_linear, final_linear)
print('sMAPE всей модели составляет','%.2f' %end_linear ,'%.')
# Out:
# sMAPE всей модели составляет 9.28 %.

# %% [markdown]
# Модель показывает вполне неплохие результаты. Посмотрим, удасться ли снизить значение симметричного среднего абсолютного процентного отклонения.

# %% [markdown]
# #### Регрессия решающго дерева.
#
# Решающее дерево - еще одна из простых моделей предсказаний. Посмотрим, будут ли показатели решающего дерева лучше, чем у линейной регрессии.

# %%
def dtr(features, target, titl):
    
    best_model = None
    best_scores = 100
    best_depth = 0
    
    for depth in range(5, 16):
    
        model_dtr = DecisionTreeRegressor(random_state=12345,
                                          max_depth = depth)
    
        scores_dtr = cross_valid(features, target, model_dtr)
    
        if scores_dtr < best_scores:
            best_scores = scores_dtr
            best_model = model_dtr
            best_depth = depth
            
    print('Лучшая модель решаюшего дерева достигнута' +
          ' при глубине дерева', best_depth, '.')
    print('На', titl,'sMAPE модели составляет',
          '%.2f' %best_scores ,'%.')
    
    return best_scores, best_model

# %%
rougher_dtr, rougher_model_dtr = \
                        dtr(features_rougher, target_rougher,
                            'этапе флотации')
# Out:
# Лучшая модель решаюшего дерева достигнута при глубине дерева 5 .
# На этапе флотации sMAPE модели составляет 6.28 %.

# %%
final_dtr, final_model_dtr = dtr(features_final, target_final,
                                 'финальном этапе')
# Out:
# Лучшая модель решаюшего дерева достигнута при глубине дерева 5 .
# На финальном этапе sMAPE модели составляет 8.60 %.

# %%
end_dtr = s_mape_final(rougher_dtr, final_dtr)
print('sMAPE всей модели составляет','%.2f' %end_dtr ,'%.')
# Out:
# sMAPE всей модели составляет 8.02 %.

# %% [markdown]
# На этапе флотации модель решающего дерева показывает результат немного хуже, чем модель линейной регрессии(6,28% против 5,75%) А на предсказании финального результата наоборот, показывает показатели лучше(8,6% против 10.46%). На данном этапе исследования, рекомендовано использовать для предсказания на этапе флотации модель линейной регрессии, а для прогноза финального этапа обработки - модель решающего дерева.
#
# Попробуем еще улучшить показатели, для этого перейдем к более сложной модели регрессии.

# %% [markdown]
# #### Случайный лес решающих деревьев.
#
# Продолжим поиск лучшей модели предсказаний со случайным лесом решающих деревьев. Поиск лучшей модели может занять некоторое время(7,5 минут для этапа флотации и 17 минут для финального этапа).

# %%
def rtr(features, target, titl):
    
    best_model = None
    best_scores = 100
    best_depth = 0
    best_n_est = 0

    for est in range(100, 121, 10):
        
        for depth in range(4, 8):
    
            model_rtr = RandomForestRegressor(random_state=12345, 
                                              n_estimators=est, 
                                              max_depth=depth)
    
            scores_rtr = cross_valid(features, target, model_rtr)

            if scores_rtr < best_scores:
                best_scores = scores_rtr
                best_model = model_rtr
                best_depth = depth
                best_n_est = est
                        
    print('Лучшая модель случайного леса достигнута при', best_n_est, 
                                   'деревьев и глубине', best_depth, '.')
    print('На', titl,'sMAPE модели составляет','%.2f' %best_scores ,'%.')
    return best_scores, best_model

# %%
rougher_rtr, rougher_model_rtr = \
                rtr(features_rougher, target_rougher, 'этапе флотации')
# Out:
# Лучшая модель случайного леса достигнута при 110 деревьев и глубине 6 .
# На этапе флотации sMAPE модели составляет 6.01 %.

# %%
final_rtr, final_model_rtr = rtr(features_final,
                                 target_final,
                                 'финальном этапе')
# Out:
# Лучшая модель случайного леса достигнута при 100 деревьев и глубине 6 .
# На финальном этапе sMAPE модели составляет 8.17 %.

# %%
end_rtr = s_mape_final(rougher_rtr, final_rtr)
print('sMAPE всей модели составляет','%.2f' %end_rtr ,'%.')
# Out:
# sMAPE всей модели составляет 7.63 %.

# %% [markdown]
# #### Лучшая модель.
#
# По результатам исследования для предсказаний результатов флотации для предсказания возьмем модель линейной регрессии, а для предсказаний результатов финальной очистки - слечайный лес решающих деревьев. Лучшие показатели модели решающего леса были при параметрах: число деревьев 100, а максимальная глубина 6.

# %%
# функция обучения модели
def model_training(features, target, model):

    # обучение модели
    model = model.fit(features, target) 
    
    predict = model.predict(features)
    
    s = s_mape(target, predict)
    
    print('Модель обучена. На обучающих данных sMAPE =', '%.2f' %s,'%.')
    
    return model, s

# %%
print('Модель предсказания результатов этапа флотация.')
rougher_model, rougher_smape = model_training(features_rougher,
                                              target_rougher, 
                                              rougher_model_linear)
# Out:
# Модель предсказания результатов этапа флотация.
# Модель обучена. На обучающих данных sMAPE = 4.78 %.

# %%
print('Модель предсказания результатов этапа финальной обработки.')
final_model, final_smape = model_training(features_final, 
                                          target_final, 
                                          final_model_rtr)
# Out:
# Модель предсказания результатов этапа финальной обработки.
# Модель обучена. На обучающих данных sMAPE = 6.21 %.

# %%
end_smape = s_mape_final(rougher_smape, final_smape)
print('sMAPE всей модели составляет','%.2f' %end_smape ,'%.')
# Out:
# sMAPE всей модели составляет 5.85 %.

# %% [markdown]
# Наша модель с использованием разных методов предсказаний для разных этапов показывает более высокий итоговый результат, чем средние значения моделие этапов обработки, обученных одним методом. Суммарное откланение всей модели на валидационной выборке составляет 8,52%, что является неплохим результатом.

# %% [markdown]
# ### Проверка лучшей моделей.
#
# Для проверки модели проведем:
# - проверку на тестовой выборке
# - проверку на адекватность
#
# #### Проверка на тестовой выборке.
#
# Проверим получившуюся модель на тестовой выборке.

# %%
predict_rougher_test = rougher_model.predict(features_rougher_test)
rougher_test = s_mape(target_rougher_test, predict_rougher_test)
print('На этапе флотации sMAPE модели составляет', 
                           '%.2f' %rougher_test,'%.')
# Out:
# На этапе флотации sMAPE модели составляет 8.23 %.

# %%
predict_final_test = final_model_rtr.predict(features_final_test)
final_test = s_mape(target_final_test, predict_final_test)
print('На финальном этапе sMAPE модели составляет', 
                              '%.2f' %final_test,'%.')
# Out:
# На финальном этапе sMAPE модели составляет 9.74 %.

# %%
end_test = s_mape_final(rougher_test, final_test)
print('sMAPE всей модели составляет','%.2f' %end_test ,'%.')
# Out:
# sMAPE всей модели составляет 9.37 %.

# %% [markdown]
# Предсказания результатов этапа флотации на тестовых данных оказались даже лучше, чем у обучающих(8,23% против 4,78%). А на предсказаниях результатов финальной обработки и результатов всей модели немного ухудшились(9,74%/9,37% против 6,21%/5,85%). Значит наша модель обучена корректно.

# %% [markdown]
# #### Проверка на адекватность.
#
# Для этого сравним результаты качества нашей модели с показателями dummy модели, по которой будем определять общее итоговое sMAPE.

# %%
dummy_regr = DummyRegressor(strategy="mean")

# %%
print('Модель предсказания результатов этапа флотация.')
rougher_dummy_model, rougher_dummy_smape = \
      model_training(features_rougher, target_rougher, dummy_regr)
# Out:
# Модель предсказания результатов этапа флотация.
# Модель обучена. На обучающих данных sMAPE = 6.96 %.

# %%
print('Модель предсказания результатов этапа финальной обработки.')
final_dummy_model, final_dummy_smape = \
      model_training(features_final, target_final, dummy_regr)
# Out:
# Модель предсказания результатов этапа финальной обработки.
# Модель обучена. На обучающих данных sMAPE = 9.44 %.

# %%
end_dummy_smape = s_mape_final(rougher_dummy_smape, final_dummy_smape)
print('sMAPE всей модели на валидационной выборке составляет',
      '%.2f' %end_dummy_smape ,'%.')
# Out:
# sMAPE всей модели на валидационной выборке составляет 8.82 %.

# %% [markdown]
# Теперь можем перейти к предсказаниям на тестовых данных.

# %%
predict_rougher_dummy = rougher_dummy_model.predict(features_rougher_test)
rougher_dummy = s_mape(target_rougher_test, predict_rougher_dummy)
print('На этапе флотации sMAPE модели составляет', 
                              '%.2f' %rougher_dummy,'%.')
# Out:
# На этапе флотации sMAPE модели составляет 29.06 %.

# %%
predict_final_dummy = final_dummy_model.predict(features_final_test)
final_dummy = s_mape(target_final_test, predict_final_dummy)
print('На финальном этапе sMAPE модели составляет', 
                              '%.2f' %final_dummy,'%.')
# Out:
# На финальном этапе sMAPE модели составляет 10.00 %.

# %%
end_dummy = s_mape_final(rougher_dummy, final_dummy)
print('sMAPE всей модели составляет','%.2f' %end_dummy,'%.')
# Out:
# sMAPE всей модели составляет 14.77 %.

# %% [markdown]
# Для наглядности сведем все полученные данные в одну таблицу.

# %%
pd.DataFrame([
    ['Обучающие данные. Флотация', 
     round(rougher_smape, 2), 
     round(rougher_dummy_smape, 2)],
    ['Обучающие данные. Финальный', 
     round(final_smape, 2),
     round(final_dummy_smape, 2)],
    ['Обучающие данные. Общее', 
     round(end_smape, 2), 
     round(end_dummy_smape, 2)],
    ['Тестовая выборка. Флотация', 
     round(rougher_test, 2), 
     round(rougher_dummy, 2)],
    ['Тестовая выборка. Финальный', 
     round(final_test, 2), 
     round(final_dummy, 2)],
    ['Тестовая выборка. Общее', 
     round(end_test, 2), 
     round(end_dummy, 2)]
              ], 
             columns=['sMAPE', 'Обученная модель' , 'Dummy модель'])
# Out:
#                          sMAPE  Обученная модель  Dummy модель
# 0   Обучающие данные. Флотация              4.78          6.96
# 1  Обучающие данные. Финальный              6.21          9.44
# 2      Обучающие данные. Общее              5.85          8.82
# 3   Тестовая выборка. Флотация              8.23         29.06
# 4  Тестовая выборка. Финальный              9.74         10.00
# 5      Тестовая выборка. Общее              9.37         14.77

# %% [markdown]
# По данным сводной таблицы видно, что обученная нами модель эффективнее Dummy модели, построенной на среднем значении.

# %% [markdown]
# ## Общий вывод.

# %% [markdown]
# Была проведена работа по анализу полученных данных. На их основании были построены и обучены модели для прогнозирования результатов обогащения и очистки золотосодержащей руды.
#
# **1. Подготовка данных**
#
# На этапе подготовки данных было рассмотрено содержимое полученных файлов, также была разработана формула для расчета эффективности обогащения(𝑅𝑒𝑐𝑜𝑣𝑒𝑟𝑦) и произведена подготовка обучающих и тестовых данных. В ходе подготовки данных были исключены пропущенные значения и столбцы избыточной информации в обучающих данных. Также для тестовых данных были восстановлены значения параметров, которые должна будут предсказывать наша модель.
#
# **2. Анализ данных**
#
# Следующим шагом нашего исследования был анализ:
# - как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки;
# - распределения размеров гранул сырья на обучающей и тестовой выборках;
# - суммарная концентрация всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# Концентрация всех металлов на этапе флотации возрастает, затем концентрация золота продолжает расти с каждым этапом, а серебра и свинца снижаться ко второму этапу очистки.
# Суммарная концентрация металлов в образцах возрастает с каждым этапом, следовательно процесс обогащения проводится правильно.
#
# **3. Модель**
#
# Затем мы перешли непосредственно к разработке моделей прогнозирования. В качестве критерия оценки качества модели был выбран sMAPE (симметричное среднее абсолютное процентное отклонение).Для этого была создана функция расчета суммарного sMAPE модели., а в качестве метода обучения кросс-валидация.
#
# | sMAPE \ модель | Линейная | Решающее дерево | Случайный лес |
# |:--------------:|:--------:|:---------------:|:-------------:|
# |Флотация        |5,75\%|6,28\%|6,01\%|
# |Финальный       |10,46\%|8,60\%|8,17\%|
# |Общее           |9,28\%|8,02\%|7,63\%|
#
# По полученным результатам был выбран следующий алгоритм предсказаний: для прогнозирования результатов флотации лучше подошла линейная модель, а для предсказания итогово концентрата – модель случайного леса решающих деревьев(количество деревьев - 100 глубиной 6).
#
# Далее модели были обучены. На обучающих данных суммарное sMAPE всей модели получилось 5,85%, что является вполне хорошим результатом.
#
# Чтобы убедиться в работе моделей были проведены две проверки – на тестовой выборке и на адекватность. В результате мы получили следующие данные:
#
# | sMAPE	                     | Обученная модель | Dummy модель |
# |:-------------------------- |:----------------:|:------------:|
# |Обучающие данные. Флотация  |4,78\%|6,96\%|
# |Обучающие данные. Финальный |6,21\%|9,44\%|
# |Обучающие данные. Общее     |5,85\%|8,82\%|
# |Тестовая выборка. Флотация  |8,23\%|29.06\%|
# |Тестовая выборка. Финальный |9,74\%|10,00\%|
# |Тестовая выборка. Общее     |9.37\%|14.77\%|
#
#
# **Вывод:** разработанная в ходе данного исследования модель пригодна для применеия в работе.
